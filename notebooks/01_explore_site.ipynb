# %% [markdown]
# # 01 - Explorar estructura de ayore.org
#
# Objetivo: Entender la estructura del sitio, descubrir páginas paralelas, y validar el scraping.

# %%
from src.scraping.utils import fetch_page
from src.scraping.crawler import discover_section_pages, build_parallel_pairs

# %%
# Explorar una sección
urls = discover_section_pages("cultura/ensenanzas")
print(f"Páginas encontradas: {len(urls)}")
for u in urls[:5]:
    print(f"  {u}")
