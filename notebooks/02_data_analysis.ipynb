# %% [markdown]
# # 02 - Análisis del corpus
#
# Objetivo: Estadísticas del corpus paralelo, cobertura, distribución de longitudes.

# %%
import json
import pandas as pd
from src.utils.config import PROJECT_ROOT

corpus_path = PROJECT_ROOT / "data" / "processed" / "parallel_corpus.jsonl"
entries = [json.loads(line) for line in open(corpus_path)]
df = pd.DataFrame(entries)
print(f"Total segments: {len(df)}")
df.head()
