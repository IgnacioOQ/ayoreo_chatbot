# %% [markdown]
# # 03 - Experimentos de POS Tagging
#
# Objetivo: Probar el POS tagger basado en reglas, evaluar cobertura del diccionario.

# %%
from src.pos_tagging.rule_engine import RuleBasedTagger, tokenize

# Ejemplo con tagger vacío
tagger = RuleBasedTagger()
text = "Dupade ome yoqui ore guejna."
tokens = tokenize(text)
tagged = tagger.tag(tokens)
print(tagged)
